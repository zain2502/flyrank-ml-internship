# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/zain2502/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
import os
import subprocess
import sys

REPO_URL = "https://github.com/zain2502/flyrank-ml-internship"
REPO_DIR = "flyrank-ml-internship"

if not os.path.exists(REPO_DIR):
    subprocess.run(
        ["git", "clone", "--depth", "1", REPO_URL, REPO_DIR],
        check=True
    )

os.chdir(REPO_DIR)

print("Current folder:", os.getcwd())
print("Files:", os.listdir())

assert os.path.exists(
    "data/raw/content_refresh_anonymized.csv"
), "Dataset not found!"

print("✅ Dataset found. Ready to continue.")
# Out:
# Current folder: /content/flyrank-ml-internship/flyrank-ml-internship
# Files: ['LICENSE', 'AGENTS.md', 'CLAUDE.md', 'data', 'outputs', 'skills', 'work', '.git', 'SETUP.md', '.github', '.gitignore', 'requirements.txt', 'README.md', 'docs', 'notebooks', 'submission', 'scripts', 'DATA_USE.md', 'GUIDE.md']
# ✅ Dataset found. Ready to continue.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
print("ML task type: Ranking")
print("Goal: prioritize content pages for human review.")
# Out:
# ML task type: Ranking
# Goal: prioritize content pages for human review.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

df["target_proxy"] = (df["trend_direction"] == "down").astype(int)

print("Target proxy distribution:")
print(df["target_proxy"].value_counts())
# Out:
# Target proxy distribution:
# target_proxy
# 1    16262
# 0    13738
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
print("Primary success metric: Precision@50")
print("Higher Precision@50 means more relevant pages appear in the top 50 recommendations.")
# Out:
# Primary success metric: Precision@50
# Higher Precision@50 means more relevant pages appear in the top 50 recommendations.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

lane_df = df[
    [
        "trend_direction",
        "search_volume",
        "impressions_90d",
        "ctr",
        "avg_position",
        "content_age_days",
        "word_count"
    ]
].copy()

print("Dataset shape:", df.shape)
print("Unit of analysis: one content page")
print("Example rows:")

lane_df.head(10)
# Out:
# Dataset shape: (30000, 44)
# Unit of analysis: one content page
# Example rows:
#   trend_direction  search_volume  impressions_90d   ctr  avg_position  \
# 0            down           10.0             3803  0.76          10.6
# 1            down           90.0            15320  0.05          20.3
# 2            down            0.0            12581  0.09          36.5
# 3          stable           10.0            11751  0.49           6.2
# 4            down            0.0            19140  0.13          44.0
# 5            down          720.0             3970  0.03           8.5
# 6            down            0.0               20  0.00           7.0
# 7          stable          590.0             1724  0.06          21.2
# 8            down            0.0            32574  0.09          46.0
# 9            down            0.0             1240  0.16           4.9
#
#    content_age_days  word_count
# 0               187      3221.0
# 1               445      2481.0
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
print("Features available for the page-level task:")
print([
    "search_volume",
    "impressions_90d",
    "ctr",
    "avg_position",
    "content_age_days",
    "word_count"
])

print("\nDecision supported:")
print("Prioritize pages for human content review.")
# Out:
# Features available for the page-level task:
# ['search_volume', 'impressions_90d', 'ctr', 'avg_position', 'content_age_days', 'word_count']
#
# Decision supported:
# Prioritize pages for human content review.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
